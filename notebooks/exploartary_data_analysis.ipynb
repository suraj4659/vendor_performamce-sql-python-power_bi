# %%
import pandas as pd
import sqlite3
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
conn = sqlite3.connect('inventory.db')

# %%
tables =pd.read_sql_query("select  name from sqlite_master where type='table'",conn)
tables
# Out:
#                    name
# 0       begin_inventory
# 1         end_inventory
# 2             purchases
# 3       purchase_prices
# 4                 sales
# 5        vendor_invoice
# 6  vendor_sales_summary

# %%
for table in tables['name']:
    print('_'*50,{table},'_'*50)
    print('count of the records:',pd.read_sql(f"select count(*) as count from {table}",conn )['count'].values[0])
    display(pd.read_sql(f"select * from {table} limit 5",conn))
# Out:
# __________________________________________________ {'begin_inventory'} __________________________________________________
# count of the records: 206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# __________________________________________________ {'end_inventory'} __________________________________________________
# ...

# %%
purchase = pd.read_sql_query(f"select * from purchases where VendorNumber = 388",conn)
purchase
# Out:
#               InventoryId  Store  Brand                Description   Size  \
# 0       76_DONCASTER_2034     76   2034  Glendalough Double Barrel  750mL
# 1    42_BLACK HOLLOW_2034     42   2034  Glendalough Double Barrel  750mL
# 2       79_BALLYMENA_2034     79   2034  Glendalough Double Barrel  750mL
# 3       32_MOUNTMEND_2034     32   2034  Glendalough Double Barrel  750mL
# 4       50_MOUNTMEND_2034     50   2034  Glendalough Double Barrel  750mL
# ..                    ...    ...    ...                        ...    ...
# 261          70_KELD_2034     70   2034  Glendalough Double Barrel  750mL
# 262   1_HARDERSFIELD_2034      1   2034  Glendalough Double Barrel  750mL
# 263     32_MOUNTMEND_2034     32   2034  Glendalough Double Barrel  750mL
# 264   59_CLAETHORPES_2034     59   2034  Glendalough Double Barrel  750mL
# 265      51_ABERDEEN_2034     51   2034  Glendalough Double Barrel  750mL
#
#      VendorNumber                   VendorName  PONumber      PODate  \
# ...

# %%
purchase_price =pd.read_sql_query(f"select * from purchase_prices where VendorNumber= 388",conn)
purchase_price
# Out:
#    Brand                   Description  Price   Size Volume  Classification  \
# 0   2034     Glendalough Double Barrel  32.99  750mL    750               1
# 1   2119  Glendalough 13 Yr Sngle Malt  89.99  750mL    750               1
# 2   7241  Glendalough Poitin Shry Cask  34.99  750mL    750               2
#
#    PurchasePrice  VendorNumber                   VendorName
# 0          21.32           388  ATLANTIC IMPORTING COMPANY
# 1          66.40           388  ATLANTIC IMPORTING COMPANY
# 2          20.68           388  ATLANTIC IMPORTING COMPANY

# %%
vendor_invoices = pd.read_sql_query("select VendorNumber,Freight from vendor_invoice",conn)
vendor_invoices
# Out:
#       VendorNumber  Freight
# 0              105     3.47
# 1             4466     8.57
# 2              388     4.61
# 3              480  2935.20
# 4              516   429.20
# ...            ...      ...
# 5538          9622     8.60
# 5539          9625   186.50
# 5540          3664   932.95
# 5541          9815   819.54
# 5542         90058    16.60
#
# [5543 rows x 2 columns]

# %%
purchase.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
purchase_price.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
vendor_sales_summary = pd.read_sql_query("""
WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
),

PurchaseSummary AS (
    SELECT
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.Description,
        p.PurchasePrice,
        pp.Price AS ActualPrice,
        pp.Volume,
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.Dollars) AS TotalPurchaseDollars
    FROM purchases p
    JOIN purchase_prices pp
        ON p.Brand = pp.Brand
    WHERE p.PurchasePrice > 0
    GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
),

SalesSummary AS (
    SELECT
        VendorNo,
        Brand,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(SalesDollars) AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(ExciseTax) AS TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
)

SELECT
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.Description,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesQuantity,
    ss.TotalSalesDollars,
    ss.TotalSalesPrice,
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.VendorNumber = ss.VendorNo
    AND ps.Brand = ss.Brand
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseDollars DESC
""", conn)

# %%
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice  ActualPrice Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99   1750
# 1            Tito's Handmade Vodka          23.19        28.99   1750
# 2                 Absolut 80 Proof          18.24        24.99   1750
# ...

# %% [markdown]
# This query generate vendor vise sales and purchase summer and it help for :
#
# performance optimaization:
# -the query involves heavy joins and aggregation on large dataset like sales and purchases
# -storing the heavy pre-aggreatoins values and for saving repeatative computations.
# -helping in analyzing sales and purchasing and pricing different vendors and brands.
# -future help for faster dashborading and reporting
# -instead of running heavy queries and dashboard can fetch more quickly from this

# %%
vendor_sales_summary.shape
# Out:
# (10692, 14)

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                    object
# TotalPurchaseQuantity      int64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %%
vendor_sales_summary['Volume']=vendor_sales_summary['Volume'].astype('float64')

# %%
vendor_sales_summary['VendorName']=vendor_sales_summary['VendorName'].str.strip()

# %%
vendor_sales_summary['VendorName'].unique()
# Out:
# array(['BROWN-FORMAN CORP', 'MARTIGNETTI COMPANIES', 'PERNOD RICARD USA',
#        'DIAGEO NORTH AMERICA INC', 'BACARDI USA INC',
#        'JIM BEAM BRANDS COMPANY', 'MAJESTIC FINE WINES',
#        'ULTRA BEVERAGE COMPANY LLP', 'STOLI GROUP,(USA) LLC',
#        'PROXIMO SPIRITS INC.', 'MOET HENNESSY USA INC', 'CAMPARI AMERICA',
#        'SAZERAC CO INC', 'CONSTELLATION BRANDS INC', 'M S WALKER INC',
#        'SAZERAC NORTH AMERICA INC.', 'PALM BAY INTERNATIONAL INC',
#        'REMY COINTREAU USA INC', 'SIDNEY FRANK IMPORTING CO',
#        'E & J GALLO WINERY', 'WILLIAM GRANT & SONS INC',
#        'HEAVEN HILL DISTILLERIES', 'DISARONNO INTERNATIONAL LLC',
#        'EDRINGTON AMERICAS', 'CASTLE BRANDS CORP.',
#        'SOUTHERN WINE & SPIRITS NE', 'STE MICHELLE WINE ESTATES',
#        'TRINCHERO FAMILY ESTATES', 'MHW LTD', 'WINE GROUP INC',
#        'PERFECTA WINES', 'LUXCO INC', 'TREASURY WINE ESTATES',
#        'DIAGEO CHATEAU ESTATE WINES', 'SHAW ROSS INT L IMP LTD',
# ...

# %%
vendor_sales_summary['grossprofit'] =vendor_sales_summary['TotalPurchaseDollars'] - vendor_sales_summary['TotalSalesQuantity']

# %%
vendor_sales_summary['profit margin']=(vendor_sales_summary['grossprofit']/vendor_sales_summary['TotalSalesDollars'])*100

# %%
vendor_sales_summary['stockturnover']=(vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchaseQuantity'])

# %%
vendor_sales_summary['purchaseratio']=(vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchaseDollars'])

# %%
vendor_sales_summary.head()
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  ActualPrice  Volume  TotalPurchaseQuantity  \
# 0          26.27        36.99  1750.0                 145080
# 1          23.19        28.99  1750.0                 164038
# 2          18.24        24.99  1750.0                 187407
# 3          16.17        22.99  1750.0                 201682
# 4          21.89        29.99  1750.0                 138109
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesDollars  \
# 0            3811251.60            142049.0         5101919.51
# ...

# %%
df = vendor_sales_summary
df
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
df.describe().T
# Out:
#                          count          mean            std           min  \
# VendorNumber           10692.0  10650.649458   18753.519148      2.000000
# Brand                  10692.0  18039.228769   12662.187074     58.000000
# PurchasePrice          10692.0     24.385303     109.269375      0.360000
# ActualPrice            10692.0     35.643671     148.246016      0.490000
# Volume                 10692.0    847.360550     664.309212     50.000000
# TotalPurchaseQuantity  10692.0   3140.886831   11095.086769      1.000000
# TotalPurchaseDollars   10692.0  30106.693372  123067.799627      0.710000
# TotalSalesQuantity     10514.0   3129.583317   11037.801407      1.000000
# TotalSalesDollars      10514.0  42954.173834  168977.755843      1.980000
# TotalSalesPrice        10514.0  19111.958773   45264.605387      0.990000
# TotalExciseTax         10514.0   1804.263569   11065.659557      0.060000
# FreightCost            10692.0  61433.763214   60938.458032      0.090000
# ...

# %%
cursor = conn.cursor()  # ✅ Correct: Call the method to get a cursor
cursor.execute("""
    CREATE TABLE vendor_sales_summary (
        VendorNumber INT,
        VendorName VARCHAR(100),
        Brand INT,
        Description VARCHAR(100),
        PurchasePrice DECIMAL(10,2),
        ActualPrice DECIMAL(10,2),
        Volume DECIMAL(15,2),
        TotalPurchaseQuantity INT,
        TotalPurchaseDollars DECIMAL(15,2),
        TotalSalesQuantity INT,
        TotalSalesDollars DECIMAL(15,2),
        TotalSalesPrice DECIMAL(15,2),
        TotalExciseTax DECIMAL(15,2),
        FreightCost DECIMAL(15,2),
        GrossProfit DECIMAL(15,2),
        ProfitMargin DECIMAL(15,2),
        StockTurnover DECIMAL(15,2),
        SalesToPurchaseRatio DECIMAL(15,2),
        PRIMARY KEY (VendorNumber, Brand)
    );
""")
conn.commit()  # ✅ Important: Commit the changes
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[25], line 2
#       1 cursor = conn.cursor()  # ✅ Correct: Call the method to get a cursor
# ----> 2 cursor.execute("""
#       3     CREATE TABLE vendor_sales_summary (
#       4         VendorNumber INT,
#       5         VendorName VARCHAR(100),
#       6         Brand INT,
#       7         Description VARCHAR(100),
#       8         PurchasePrice DECIMAL(10,2),
#       9         ActualPrice DECIMAL(10,2),
#      10         Volume DECIMAL(15,2),
#      11         TotalPurchaseQuantity INT,
#      12         TotalPurchaseDollars DECIMAL(15,2),
#      13         TotalSalesQuantity INT,
#      14         TotalSalesDollars DECIMAL(15,2),
#      15         TotalSalesPrice DECIMAL(15,2),
#      16         TotalExciseTax DECIMAL(15,2),
#      17         FreightCost DECIMAL(15,2),
#      18         GrossProfit DECIMAL(15,2),
# ...

# %%
vendor_sales_summary

# %%
vendor_sales_summary.to_sql('vendor_sales_summary',conn,if_exists='replace',index =False )

# %%
#distribution plots for numerical columna 
numerical_cols = df.select_dtypes(include = np.number).columns



plt.figure(figsize = (19,19))
for i,col in enumerate(numerical_cols):
    plt.subplot(4,4,i+1)
    sns.histplot(df[col],kde=True,bins = 30)
    plt.title(col)
plt.tight_layout
plt.show

# %%
numerical_cols = df.select_dtypes(include = np.number).columns



plt.figure(figsize = (19,10))
for i,col in enumerate(numerical_cols):
    plt.subplot(4,4,i+1)
    sns.boxplot(df[col])
    plt.title(col)
plt.tight_layout
plt.show

# %%
catagorial_cols =["VendorName","Description"]



plt.figure(figsize = (11,6))
for i,col in enumerate(catagorial_cols):
    plt.subplot(2,1,i+1)
    sns.countplot(df[col],order =df[col].value_counts().index[:10])
    plt.title(col)
plt.tight_layout
plt.show
